# %%
# String Concatenation

string1 = "Hello "
name = input("Enter your Name:Bade Madhuri ")

# Concatenate string1 and name
result = string1 + name
print(result)

# Add string3
string3 = ", welcome to Python programming"
result = result + string3

print(result)
# Out:
# Enter your Name:Bade Madhuri Bade Madhuri
# Hello Bade Madhuri
# Hello Bade Madhuri, welcome to Python programming

# %%
# Existing concatenated string
name = input("Enter your Name: ")

string1 = "Hello "
string3 = ", welcome to Python programming"

text = string1 + name + string3

print("\nOriginal String:", text)
# Out:
# Enter your Name: Bade Madhuri
#
# Original String: Hello Bade Madhuri, welcome to Python programming

# %%
# a. First character
print("a. First character:", text[0])
# b. Last character
print("b. last character:", text[-1])
# c. First 5 characters
print("c. First 5 characters:", text[:5])

# d. Last 11 characters
print("d. Last 11 characters:", text[-11:])

# e. Reverse the string
print("e. Reverse:", text[::-1])

# f. Print the word "Python"
python_start = text.index("Python")
print("f. Word Python:", text[python_start:python_start + 6])
# Out:
# a. First character: H
# b. last character: g
# c. First 5 characters: Hello
# d. Last 11 characters: programming
# e. Reverse: gnimmargorp nohtyP ot emoclew ,iruhdaM edaB olleH
# f. Word Python: Python

# %%
#strings method
strM = "Python beginner tutorial"

# a. Convert the sentence to uppercase
print("a. Uppercase:", strM.upper())

# b. Convert the sentence to lowercase
print("b. Lowercase:", strM.lower())

# c. Capitalize the sentence
print("c. Capitalize:", strM.capitalize())

# d. Count the occurrences of character 't'
print("d. Count of 't':", strM.count('t'))

# e. Replace "Python" with "Machine Learning"
print("e. Replaced string:", strM.replace("Python", "Machine Learning"))
# Out:
# a. Uppercase: PYTHON BEGINNER TUTORIAL
# b. Lowercase: python beginner tutorial
# c. Capitalize: Python beginner tutorial
# d. Count of 't': 3
# e. Replaced string: Machine Learning beginner tutorial

# %%
#tuples
# Create two tuples
t1 = (10, 20, 30)
t2 = (40, 50, 60)

# a. Concatenate the two tuples
t_combine = t1 + t2
print("a. Combined tuple:", t_combine)

# b. Repeat the elements of t_combine 3 times
t_repeat = t_combine * 3
print("b. Repeated tuple:", t_repeat)

# c. Access the 3rd element
print("c. 3rd element:", t_combine[2])

# d. Access the first three elements
print("d. First three elements:", t_combine[:3])

# e. Access the last three elements
print("e. Last three elements:", t_combine[-3:])
# Out:
# a. Combined tuple: (10, 20, 30, 40, 50, 60)
# b. Repeated tuple: (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)
# c. 3rd element: 30
# d. First three elements: (10, 20, 30)
# e. Last three elements: (40, 50, 60)

# %%
#List creation
# a. Create age_list with five integer elements
age_list = [24, 25, 26, 27, 28]

# b. Create name_list with five string elements
name_list = ["Alice", "Bob", "Charlie", "David", "Emma"]

print("Age List:", age_list)
print("Name List:", name_list)
# Out:
# Age List: [24, 25, 26, 27, 28]
# Name List: ['Alice', 'Bob', 'Charlie', 'David', 'Emma']

# %%
#List operation and modification
# Initial lists
age_list = [24, 25, 26, 27, 28]
name_list = ["Alice", "Bob", "Charlie", "David", "Emma"]
# a. Append "Yazhini" to name_list
name_list.append("Yazhini")
print("a. After append:", name_list)

# b. Insert 30 at index 2 in age_list
age_list.insert(2, 30)
print("b. After insert:", age_list)

# c. Remove "Yazhini" from name_list
name_list.remove("Yazhini")
print("c. After remove:", name_list)

# d. Pop the last element from age_list
age_list.pop()
print("d. After pop:", age_list)

# e. Extend age_list with additional ages
age_list.extend([29, 30, 26])
print("e. After extend:", age_list)

# f. Sort age_list in descending order
age_list.sort(reverse=True)
print("f. Descending order:", age_list)

# g. Find Max, Min and Sum of ages
print("g. Maximum age:", max(age_list))
print("   Minimum age:", min(age_list))
print("   Sum of all ages:", sum(age_list))
# Out:
# a. After append: ['Alice', 'Bob', 'Charlie', 'David', 'Emma', 'Yazhini']
# b. After insert: [24, 25, 30, 26, 27, 28]
# c. After remove: ['Alice', 'Bob', 'Charlie', 'David', 'Emma']
# d. After pop: [24, 25, 30, 26, 27]
# e. After extend: [24, 25, 30, 26, 27, 29, 30, 26]
# f. Descending order: [30, 30, 29, 27, 26, 26, 25, 24]
# g. Maximum age: 30
#    Minimum age: 24
#    Sum of all ages: 217

# %%
#accessing list and elements
name_list = ["Alice", "Bob", "Charlie", "David", "Emma"]

# a. Print the first element
print("a. First element:", name_list[0])

# b. Print the last element
print("b. Last element:", name_list[-1])

# c. Print elements from index 2 to index 4
print("c. Elements from index 2 to 4:", name_list[2:5])

# d. Print the elements in reverse order
print("d. Reverse order:", name_list[::-1])
# Out:
# a. First element: Alice
# b. Last element: Emma
# c. Elements from index 2 to 4: ['Charlie', 'David', 'Emma']
# d. Reverse order: ['Emma', 'David', 'Charlie', 'Bob', 'Alice']

# %%
#Dictionary (Creation, Modification and Access):
# a. Create a dictionary with five students and their marks
student_marks = {
    "Ravi": 75,
    "Priya": 88,
    "Arun": 92,
    "Sneha": 67,
    "Kiran": 81
}

# b. Access and print the mark of a specific student
print("b. Marks of Priya:", student_marks["Priya"])

# c. Add a new student "Janani" with marks 80
student_marks["Janani"] = 80

# d. Update the mark of an older student to 82
student_marks["Ravi"] = 82

# e. Print all keys, values, and key-value pairs
print("e. Student Names:", student_marks.keys())
print("   Marks:", student_marks.values())
print("   Student-Mark Pairs:", student_marks.items())
# Out:
# b. Marks of Priya: 88
# e. Student Names: dict_keys(['Ravi', 'Priya', 'Arun', 'Sneha', 'Kiran', 'Janani'])
#    Marks: dict_values([82, 88, 92, 67, 81, 80])
#    Student-Mark Pairs: dict_items([('Ravi', 82), ('Priya', 88), ('Arun', 92), ('Sneha', 67), ('Kiran', 81), ('Janani', 80)])

# %%
#sets(operations)
# a. Create a set with the given values
my_set = {'a', 'e', 'i', 'o', 'u', 'a', 'a', 'i'}

print("a. my_set:", my_set)

# b. Attempt to change the value at index 4
my_set.add('s')
# Out:
# a. my_set: {'a', 'o', 'u', 'i', 'e'}

# %%
# c. Create two sets
set1 = {1, 3, 5, 7, 9}
set2 = {2, 3, 5, 8, 10}

# d. Find union and intersection
union_set = set1.union(set2)
intersection_set = set1.intersection(set2)

print("Union:", union_set)
print("Intersection:", intersection_set)
set1.union(set2)
set1.intersection(set2)
# Out:
# Union: {1, 2, 3, 5, 7, 8, 9, 10}
# Intersection: {3, 5}
# {3, 5}

# %%
# Performance Category Program

score = float(input("Enter your score (0-10): "))

if score < 0 or score > 10:
    print("Invalid score! Please enter a score between 0 and 10.")

elif score > 7:
    print("Performance Category: Above Average")
    print("Excellent performance! Keep up the great work.")

elif score >= 4:
    print("Performance Category: Average")
    print("Good effort! Keep practicing to improve your performance.")

else:
    print("Performance Category: Below Average")
    print("Need to improve your performance. Consistent practice will lead to better results.")
# Out:
# Enter your score (0-10): 7
# Performance Category: Average
# Good effort! Keep practicing to improve your performance.

# %% [markdown]
# #Python Assignment 3: While Loop, For loop and Function

# %%
import random

number = random.randint(1, 10)

print("Guess a number between 1 and 10")
# Out:
# Guess a number between 1 and 10

# %%
attempts = 3

guess = int(input("Enter your guess (1-10): "))

print("You guessed:", guess)
print("Attempts allowed:", attempts)
# Out:
# Enter your guess (1-10): 5
# You guessed: 5
# Attempts allowed: 3

# %%
import random

number = random.randint(1, 10)

print("Guess a number between 1 and 10")

attempts = 3

while attempts > 0:
    guess = int(input("Enter your guess: "))

    if guess < 1 or guess > 10:
        print("Please enter a number between 1 and 10.")
        continue

    if guess > number:
        print("Your guess is too high.")

    elif guess < number:
        print("Your guess is too low.")

    else:
        print("Congratulations! You guessed the correct number.")
        break

    attempts = attempts - 1
    print("Attempts remaining:", attempts)
# Out:
# Guess a number between 1 and 10
# Enter your guess: 6
# Your guess is too low.
# Attempts remaining: 2
# Enter your guess: 5
# Your guess is too low.
# Attempts remaining: 1
# Enter your guess: 9
# Your guess is too high.
# Attempts remaining: 0

# %% [markdown]
# For Loop Multiplication Table Generator

# %%
number = int(input("Enter a number: "))

for i in range(1, 11):
    result = number * i
    print(number, "x", i, "=", result)
# Out:
# Enter a number: 6
# 6 x 1 = 6
# 6 x 2 = 12
# 6 x 3 = 18
# 6 x 4 = 24
# 6 x 5 = 30
# 6 x 6 = 36
# 6 x 7 = 42
# 6 x 8 = 48
# 6 x 9 = 54
# 6 x 10 = 60

# %% [markdown]
# BMI Calculator

# %%
def calculate_bmi(weight, height):
    bmi = weight / (height ** 2)
    return bmi


weight = float(input("Enter your weight in kg: "))
height = float(input("Enter your height in meters: "))

bmi = calculate_bmi(weight, height)

print("Your BMI is:", round(bmi, 2))
# Out:
# Enter your weight in kg: 45
# Enter your height in meters: 55
# Your BMI is: 0.01
